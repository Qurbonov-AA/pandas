# %%
import pandas as pd

# %%
df = pd.read_csv("population/countries/afghanistan-population.csv")
df
# Out:
#         country  Year  Population Yearly %   Change  Yearly  Change  \
# 0   Afghanistan  2020    38928346            2.33 %          886592
# 1   Afghanistan  2019    38041754            2.34 %          869833
# 2   Afghanistan  2018    37171921            2.41 %          875808
# 3   Afghanistan  2017    36296113            2.58 %          913081
# 4   Afghanistan  2016    35383032            2.82 %          969429
# 5   Afghanistan  2015    34413603            3.35 %         1045619
# 6   Afghanistan  2010    29185507            2.61 %          706246
# 7   Afghanistan  2005    25654277            4.30 %          974865
# 8   Afghanistan  2000    20779953            2.79 %          533859
# 9   Afghanistan  1995    18110657            7.85 %         1139670
# 10  Afghanistan  1990    12412308            0.78 %           94820
# 11  Afghanistan  1985    11938208           -2.22 %         -283661
# 12  Afghanistan  1980    13356511            1.03 %          133470
# ...

# %%
df.head(7)
# Out:
#        country  Year  Population Yearly %   Change  Yearly  Change  \
# 0  Afghanistan  2020    38928346            2.33 %          886592
# 1  Afghanistan  2019    38041754            2.34 %          869833
# 2  Afghanistan  2018    37171921            2.41 %          875808
# 3  Afghanistan  2017    36296113            2.58 %          913081
# 4  Afghanistan  2016    35383032            2.82 %          969429
# 5  Afghanistan  2015    34413603            3.35 %         1045619
# 6  Afghanistan  2010    29185507            2.61 %          706246
#
#    Migrants (net)  Median Age  Fertility Rate  Density (P/Km²) Urban  Pop %  \
# 0          -62920        18.4            4.56               60       25.4 %
# 1          -62920        17.4            5.26               58       25.2 %
# 2          -62920        17.4            5.26               57       24.9 %
# 3          -62920        17.4            5.26               56       24.7 %
# ...

# %%
df.tail(3)
# Out:
#         country  Year  Population Yearly %   Change  Yearly  Change  \
# 15  Afghanistan  1965     9956320            2.05 %          191869
# 16  Afghanistan  1960     8996973            1.70 %          145196
# 17  Afghanistan  1955     8270991            1.30 %          103775
#
#     Migrants (net)  Median Age  Fertility Rate  Density (P/Km²) Urban  Pop %  \
# 15           -4000        18.4            7.45               15        9.9 %
# 16           -4000        18.8            7.45               14        8.4 %
# 17           -4000        19.2            7.45               13        7.1 %
#
#     Urban Population Country's Share of  World Pop  World Population  Rank
# 15            984350                        0.30 %        3339583597    48
# 16            755797                        0.30 %        3034949748    48
# 17            587818                        0.30 %        2773019936    48

# %%
df[ df["Year"] > 2000 ]
# Out:
#        country  Year  Population Yearly %   Change  Yearly  Change  \
# 0  Afghanistan  2020    38928346            2.33 %          886592
# 1  Afghanistan  2019    38041754            2.34 %          869833
# 2  Afghanistan  2018    37171921            2.41 %          875808
# 3  Afghanistan  2017    36296113            2.58 %          913081
# 4  Afghanistan  2016    35383032            2.82 %          969429
# 5  Afghanistan  2015    34413603            3.35 %         1045619
# 6  Afghanistan  2010    29185507            2.61 %          706246
# 7  Afghanistan  2005    25654277            4.30 %          974865
#
#    Migrants (net)  Median Age  Fertility Rate  Density (P/Km²) Urban  Pop %  \
# 0          -62920        18.4            4.56               60       25.4 %
# 1          -62920        17.4            5.26               58       25.2 %
# 2          -62920        17.4            5.26               57       24.9 %
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot(df["Year"], df["Population"])
plt.ylabel('Avgonistonning yillar kesimida aholisini uzgarishi')
plt.show()
