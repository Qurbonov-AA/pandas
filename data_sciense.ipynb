# %%
import pandas as pd
# pandas kutubxonasini import qilamiz!!!

# %%
df = pd.read_csv("population/wp.csv")

# %%
df.columns
# data setdagi barcha ustunlarni list ko'rinishida chiqaradi!
# Out:
# Index(['country', 'Year', 'Population', 'Yearly %   Change', 'Yearly  Change',
#        'Migrants (net)', 'Median Age', 'Fertility Rate', 'Density (P/Km²)',
#        'Urban  Pop %', 'Urban Population', 'Country's Share of  World Pop',
#        'World Population', 'Rank'],
#       dtype='object')

# %%
df[['country', 'Year', 'Population', 'Migrants (net)', 'Median Age',  'Density (P/Km²)',
       'World Population', 'Rank']]
# Agar bizga aynan qaysidir bir yoki bir necha ustun kerak bo'lsa df[[]]
# Out:
#           country  Year  Population  Migrants (net)  Median Age  \
# 0     Afghanistan  2020    38928346        -62920.0        18.4
# 1     Afghanistan  2019    38041754        -62920.0        17.4
# 2     Afghanistan  2018    37171921        -62920.0        17.4
# 3     Afghanistan  2017    36296113        -62920.0        17.4
# 4     Afghanistan  2016    35383032        -62920.0        17.4
# ...           ...   ...         ...             ...         ...
# 4191     Zimbabwe  1975     6293875         -9109.0        15.4
# 4192     Zimbabwe  1970     5289303         -8400.0        15.6
# 4193     Zimbabwe  1965     4471177         -3002.0        16.0
# 4194     Zimbabwe  1960     3776681         -1501.0        17.2
# 4195     Zimbabwe  1955     3213286          -901.0        18.1
#
#       Density (P/Km²)  World Population  Rank
# 0                  60        7794798739    37
# 1                  58        7713468100    37
# 2                  57        7631091040    38
# ...

# %%
df[df["Year"] == 2020].tail(40)
# datasetni pastki qatordan boshlab 20 ta ma'lumotni chiqaradi.
# Out:
#                            country  Year  Population Yearly %   Change  \
# 3408               Solomon Islands  2020      686884            2.55 %
# 3426                       Somalia  2020    15893222            2.92 %
# 3444                  South Africa  2020    59308690            1.28 %
# 3462                   South Korea  2020    51269185            0.09 %
# 3480                   South Sudan  2020    11193725            1.19 %
# 3498                         Spain  2020    46754778            0.04 %
# 3516                     Sri Lanka  2020    21413249            0.42 %
# 3534            State Of Palestine  2020     5101414            2.41 %
# 3552                         Sudan  2020    43849260            2.42 %
# 3570                      Suriname  2020      586632            0.90 %
# 3588                     Swaziland  2020     1160164            1.05 %
# 3606                        Sweden  2020    10099265            0.63 %
# ...

# %%
df2 = df[df["Year"] == 2019].head(20)
# Datasetdagi yuqoridan boshlab 20 ta ma'lumotni chiqaradi.
df2
# Out:
#                  country  Year  Population Yearly %   Change  Yearly  Change  \
# 1            Afghanistan  2019    38041754            2.34 %          869833
# 19               Albania  2019     2880917           -0.06 %           -1823
# 37               Algeria  2019    43053054            1.95 %          824646
# 54        American Samoa  2019       55312           -0.28 %            -153
# 71               Andorra  2019       77142            0.18 %             136
# 89                Angola  2019    31825295            3.30 %         1015508
# 106             Anguilla  2019       14869            0.94 %             138
# 124  Antigua And Barbuda  2019       97118            0.86 %             832
# 142            Argentina  2019    44780677            0.95 %          419527
# 160              Armenia  2019     2957731            0.20 %            5986
# 178                Aruba  2019      106314            0.44 %             469
# ...

# %%
df[df["country"] == "Uzbekistan"][1:12] # 5 ta ma'lumot chiqaradi
# bizga kerakli bo'lgan qatorlarning biz tomonimizdan belgilab bergan boshlang'ich va oxirgi nuqtalarini chiqaradi
# Out:
#          country  Year  Population Yearly %   Change  Yearly  Change  \
# 4036  Uzbekistan  2019    32981716            1.56 %          505472
# 4037  Uzbekistan  2018    32476244            1.62 %          516459
# 4038  Uzbekistan  2017    31959785            1.65 %          518034
# 4039  Uzbekistan  2016    31441751            1.66 %          512194
# 4040  Uzbekistan  2015    30929557            1.64 %          482730
# 4041  Uzbekistan  2010    28515909            1.53 %          417624
# 4042  Uzbekistan  2005    26427789            1.30 %          331567
# 4043  Uzbekistan  2000    24769955            1.68 %          395786
# 4044  Uzbekistan  1995    22791026            2.24 %          478536
# 4045  Uzbekistan  1990    20398348            2.46 %          467413
# 4046  Uzbekistan  1985    18061284            2.58 %          432505
#
#       Migrants (net)  Median Age  Fertility Rate  Density (P/Km²)  \
# 4036         -8863.0        26.5            2.43               78
# ...

# %%
df.describe()
# Out:
#               Year    Population  Yearly  Change  Migrants (net)   Median Age  \
# count  4196.000000  4.196000e+03    4.196000e+03    3.618000e+03  3618.000000
# mean   1993.957340  2.442938e+07    3.297777e+05   -4.818684e+00    25.474986
# std      21.686153  1.067293e+08    1.334212e+06    1.060564e+05     8.218262
# min    1955.000000  6.440000e+02   -6.730240e+05   -1.077397e+06    14.400000
# 25%    1975.000000  2.855070e+05    1.324250e+03   -1.228375e+04    18.500000
# 50%    1995.000000  3.685932e+06    3.892450e+04   -9.000000e+02    22.750000
# 75%    2016.000000  1.305111e+07    2.075432e+05    5.000000e+03    31.600000
# max    2020.000000  1.439324e+09    2.067648e+07    1.771991e+06    48.400000
#
#        Fertility Rate  Density (P/Km²)  World Population         Rank
# count     3618.000000      4196.000000      4.196000e+03  4196.000000
# mean         3.887186       343.500953      5.677487e+09   117.185653
# ...

# %%
df2 = df[ df["Yearly  Change"] < 0 ]

# %%
df.columns
# Out:
# Index(['country', 'Year', 'Population', 'Yearly %   Change', 'Yearly  Change',
#        'Migrants (net)', 'Median Age', 'Fertility Rate', 'Density (P/Km²)',
#        'Urban  Pop %', 'Urban Population', 'Country's Share of  World Pop',
#        'World Population', 'Rank'],
#       dtype='object')

# %%
df2[df2["Year"] == 2020]
# Out:
#                            country  Year  Population Yearly %   Change  \
# 18                         Albania  2020     2877797           -0.11 %
# 321                        Belarus  2020     9449323           -0.03 %
# 446         Bosnia And Herzegovina  2020     3280819           -0.61 %
# 535                       Bulgaria  2020     6948445           -0.74 %
# 892                        Croatia  2020     4105267           -0.61 %
# 910                           Cuba  2020    11326616           -0.06 %
# 1357                       Georgia  2020     3989167           -0.19 %
# 1428                        Greece  2020    10423054           -0.48 %
# 1660                       Hungary  2020     9660351           -0.25 %
# 1821                         Italy  2020    60461826           -0.15 %
# 1857                         Japan  2020   126476461           -0.30 %
# 2001                        Latvia  2020     1886198           -1.08 %
# ...
